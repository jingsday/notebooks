# %%
import os
import numpy as np
import pandas as pd
import scanpy as sc
import loompy as lp
from MulticoreTSNE import MulticoreTSNE as TSNE
import seaborn as sns
import matplotlib.pyplot as plt
import scipy
import csv
import gzip
import anndata as ad
from pathlib import Path
import glob

sc.settings.verbosity = 3 # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
sc.set_figure_params(dpi=150, fontsize=10, dpi_save=600)
# Out:
# -----
# anndata     0.8.0
# scanpy      1.9.1
# -----
# MulticoreTSNE               NA
# PIL                         9.2.0
# backcall                    0.2.0
# beta_ufunc                  NA
# binom_ufunc                 NA
# bottleneck                  1.3.5
# cffi                        1.15.1
# cloudpickle                 2.0.0
# colorama                    0.4.5
# cycler                      0.10.0
# cython_runtime              NA
# cytoolz                     0.11.0
# dask                        2022.7.0
# dateutil                    2.8.2
# debugpy                     1.5.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# entrypoints                 0.4
# fsspec                      2022.7.1
# h5py                        3.7.0
# hypergeom_ufunc             NA
# igraph                      0.10.2
# ipykernel                   6.15.2
# ipython_genutils            0.2.0
# ipywidgets                  7.6.5
# jedi                        0.18.1
# ...

# %%
def sce(sample1,sample2):

    #set corresponding folders which the results of each specimen are written to
  

    f_db_glob = "/home/jing/scratch/resource/*feather"
    f_db_names = ' '.join( glob.glob(f_db_glob) )

    # motif databases
    f_motif_path = "/home/jing/scratch/resource/motifs-v9-nr.hgnc-m0.001-o0.0.tbl"
    f_tfs = "/home/jing/scratch/resource/allTFs_hg38.txt"
    
    output_folder = "/home/jing/projects/samples/"
    output_path1 = os.path.join(output_folder, sample1)
    output_path2 = os.path.join(output_folder, sample1)
    
    f_loom_path_scenic = f"{output_folder}/filtered_scenic.loom"
    #os.chdir(output_path)

    # path to  loom file

    f_anndata_path = f"{output_path}/anndata.h5ad"
    f_pyscenic_output = f"{output_path}/output.loom"
    f_final_loom = f"{output_path}/scenic_integrated-output.loom"
    
    adata1 = sc.read_h5ad(os.path.join(input_folder, sample1, "tomerge.h5ad"))
    ds1 = loompy.connect("file1.loom")
    # Load the second loom file
    ds2 = loompy.connect("file2.loom")
    # Combine the two files into one
    merged_ds = loompy.combine([ds1, ds2], key="merged")

    # Save the merged file
    merged_ds.to_loom("merged.loom")
    #I
    # !pyscenic grn {f_loom_path_scenic} {f_tfs} -o adj.csv --num_workers 8
    adjacencies = pd.read_csv("adj.csv", index_col=False, sep='\t')

    adjacencies.head()
    
    #II
   
    # !pyscenic ctx adj.csv \
        {f_db_names} \
        --annotations_fname {f_motif_path} \
        --expression_mtx_fname {f_loom_path_scenic} \
        --output reg.csv \
        --mask_dropouts \
        --num_workers 8
    
    
   #III     
    # !pyscenic aucell \
        {f_loom_path_scenic} \
        reg.csv \
        --output {f_pyscenic_output} \
        --num_workers 8
    
    lf = lp.connect(f_pyscenic_output, mode='r+', validate=False)

    auc_mtx = pd.DataFrame( lf.ca.RegulonsAUC, index=lf.ca.CellID)
    lf.close()
    auc_mtx.to_pickle('auc_mtx.pickle')

# %%
sce('SF3448')
# Out:
# 2023-04-26 18:30:09,802 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2023-04-26 18:30:12,051 - pyscenic.cli.pyscenic - INFO - Inferring regulatory networks.
# /home/jing/anaconda3/lib/python3.9/site-packages/distributed/node.py:179: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 46287 instead
#   warnings.warn(
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# ...

# %%
# !pip install conicsmat
# Out:
# ERROR: Could not find a version that satisfies the requirement conicsmat (from versions: none)
# ERROR: No matching distribution found for conicsmat

# %%
# !pipenv install connected_conics
# Out:
# /bin/bash: line 1: pipenv: command not found

# %%
# !git clone https://jingsday:<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>@https://github.com/diazlab/CONICS
# Out:
# /bin/bash: line 1: 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: No such file or directory

# %%
# !git clone https://github.com/fabia-team/conicsmat.git
# Out:
# Cloning into 'conicsmat'...
# Username for 'https://github.com': ^C

# %%
cd conicsmat

# %%
# !pip install -r requirements.txt

# %%
# !pip install .

# %%
import conicsmat
